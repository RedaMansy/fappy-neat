# %%
import math
import numpy as np
import tensorflow as tf 
import sys
import os
import random
import time
import flappy_bird_gym
import yaml
import pygame

LOCAL_PATH=os.path.abspath('')
MAIN_PATH=LOCAL_PATH+''

CONF_PATH=MAIN_PATH+"/CONF"
DEMO_PATH=MAIN_PATH+"/DEMO"
DOC_PATH=MAIN_PATH+"/DOC"
ENV_PATH=MAIN_PATH+"/LIB/GAME"
LIB_PATH=MAIN_PATH+"/LIB"
LOG_PATH=MAIN_PATH+"/LOG"
IMG_PATH=MAIN_PATH+"/Images"
POLICIES_PATH=MAIN_PATH+"/POLICIES"
TEMP_PATH=MAIN_PATH+"/TEMP"
TRN_PATH=MAIN_PATH+"/LIB/TRAINING"

sys.path.insert(1, ENV_PATH)
sys.path.insert(1, TRN_PATH)
sys.path.insert(1, LIB_PATH)

class DQN(tf.keras.Model):
    def __init__(self,n_actions=4,fc1_dims=512):
        super().__init__()
        self.n_actions=n_actions
        self.fc1_dims=fc1_dims
        self.d0 = tf.keras.layers.Flatten()
        self.d1 = tf.keras.layers.Dense(self.fc1_dims,activation='relu')
        self.q_values = tf.keras.layers.Dense(self.n_actions,activation='linear')
        
    def call(self, state):
        x = tf.convert_to_tensor(state)
        x = self.d0(x)
        x = self.d1(x)
        x = self.q_values(x)
        return x
    
class ReplayBuffer():
    def __init__(self, buffer_size=50000,input_shape=[0,0,0,0]):
        self.buffer_size = buffer_size
        self.input_shape=input_shape
        self.state_mem = np.zeros((self.buffer_size,*(self.input_shape)), dtype=np.float32)
        self.action_mem = np.zeros((self.buffer_size), dtype=np.int32)
        self.reward_mem = np.zeros((self.buffer_size), dtype=np.float32)
        self.next_state_mem = np.zeros((self.buffer_size,*(self.input_shape)), dtype=np.float32)
        self.done_mem = np.zeros((self.buffer_size), dtype=np.bool)
        self.pointer = 0

    def add_exp(self, state, action, reward, next_state, done):
        idx  = self.pointer % self.buffer_size 
        self.state_mem[idx] = state
        self.action_mem[idx] = action
        self.reward_mem[idx] = reward
        self.next_state_mem[idx] = next_state
        self.done_mem[idx] = 1 - int(done)
        self.pointer += 1

    def sample_exp(self, batch_size= 64):
        max_mem = min(self.pointer, self.buffer_size)
        batch = np.random.choice(max_mem, batch_size, replace=False)
        states = self.state_mem[batch]
        actions = self.action_mem[batch]
        rewards = self.reward_mem[batch]
        next_states = self.next_state_mem[batch]
        dones = self.done_mem[batch]

        return states, actions, rewards, next_states, dones

class SimpleQAgent():
    def __init__(self, gamma=0.99, replace=100, lr=0.05,n_actions=2,input_shape=[0,0,0,0],buffer_size= 50000,batch_size=64):
        self.buffer_size = buffer_size
        self.input_shape=input_shape
        self.n_actions=n_actions
        self.gamma = gamma
        self.epsilon = 1.0
        self.min_epsilon = 0.01
        self.epsilon_decay = 1e-3
        self.replace = replace
        self.trainstep = 0
        self.memory = ReplayBuffer(input_shape=self.input_shape,buffer_size=self.buffer_size)
        self.batch_size = batch_size
        self.q_net = DQN()
        self.target_net = DQN()
        opt = tf.keras.optimizers.Adam(learning_rate=lr)
        self.q_net.compile(loss='huber', optimizer=opt)
        self.target_net.compile(loss='huber', optimizer=opt)

    def update_mem(self, state, action, reward, next_state, done):
        self.memory.add_exp(state, action, reward, next_state, done)

    def update_target(self):
        self.target_net.set_weights(self.q_net.get_weights())  

    def act(self, state):
        if np.random.rand() <= self.epsilon:
            return np.random.choice([i for i in range(self.n_actions)],p=[0.93,0.07]),False
        else:
            state=tf.convert_to_tensor([state.flatten()],dtype=tf.float32)
            actions = self.q_net(state)
            action = np.argmax(actions)
            return action,True

    # def update_mem(self, state, action, reward, next_state, done):
    #     self.memory.add_exp(state, action, reward, next_state, done)

    def update_target(self):
        self.target_net.set_weights(self.q_net.get_weights())   

    def update_epsilon(self):
        self.epsilon = self.epsilon - self.epsilon_decay if self.epsilon > self.min_epsilon else self.min_epsilon
        return self.epsilon

    def train_simple(self):
        if self.memory.pointer < self.batch_size:
            return 0,0
        with tf.GradientTape() as tape:
            states, actions, rewards, next_states, dones = self.memory.sample_exp(self.batch_size)
            target = self.q_net(states)
            q_next = tf.math.reduce_max(self.target_net(next_states), axis=1,keepdims=True).numpy()
            q_target = np.copy(target)  #optional  
            maxq=tf.reduce_mean(tf.math.reduce_max(target, axis=1,keepdims=True).numpy())
            for idx, terminal in enumerate(dones):
                if terminal:
                    q_next[idx]=0.0
                q_target[idx,actions[idx]]=rewards[idx]+self.gamma*q_next[idx]
            loss=tf.reduce_mean((q_target-target)**2)
        gradient= tape.gradient(loss,self.q_net.trainable_variables)
        self.q_net.optimizer.apply_gradients(zip(gradient,self.q_net.trainable_variables))
        self.trainstep += 1
        return float(maxq.numpy()),float(1)

class DQL:
    def __init__(self):
        print("Flappy Bird Training")
        pygame.init()
        pygame.display.set_caption("Flappy Bird")
        self.experiment_name="dql"
        self.n_actions,self.max_epochs,self.max_episodes,self.max_steps,self.max_e,self.min_e,self.e_decay,self.w_updates,self.t_updates,self.t_steps,self.mini_batch_size,self.max_queue_length=self.load_params(CONF_PATH)
        self.environment=flappy_bird_gym.make("FlappyBird-v0",pipe_gap = 150)
        s = self.environment.reset()

        self.environment.step(0)
        self.agente=SimpleQAgent(n_actions=2,input_shape=s.shape,buffer_size=self.max_queue_length,batch_size=self.mini_batch_size)
        self.state=tf.convert_to_tensor([s.flatten()],dtype=tf.float32)
        self.agente.q_net(self.state)
        self.agente.target_net(self.state)
        self.rtrn = []
        self.avg_r = []
        self.loss = []
        self.loss_avg = []
        self.max_q_net = []
        self.max_q_net_avg = []
        self.environment.dt = 30.0/1000.0

    def episode_training(self,mode):
        normal=False
        if mode=="random":
            print("Episode training random")
            name="random_episodes"
            epsilon=1.0
        else:
            print("Episode training ",self.experiment_name)
            name=self.experiment_name+"_episodes"
            normal=True

        episode=0
        weight_updates=0
        step_num=0
        rwd=0
        rwd_nn=0
        avg_r_nn=[0]
        avg_r=[0]
        eoe_avg_r=[0]
        Rtrn=[0]
        eoe_Rtrn=[0]
        Rtrn_nn=[0]

        biased=0
        while episode<self.max_episodes:
            episode+=1
            d=False
            expert_action=False
            s=self.environment.reset()
            action=self.agente.act(s)
            Rtrn.append(rwd)
            eoe_Rtrn.append(rwd)
            Rtrn_nn.append(rwd_nn)
            # eoe_Rtrn_nn.append(rwd_nn)
            rwd=0
            rwd_nn=0
            last_score=0
            while not d:
                #time.sleep(0.1)
                step_num+=1
                if step_num==self.max_steps:
                    break
                for event in pygame.event.get():
                    if event.type == pygame.QUIT:
                        pygame.quit()
                if normal:
                    self.agente.epsilon= self.min_e + (self.max_e - self.min_e) * np.exp(-self.e_decay*(episode))
                    action,nn=self.agente.act(s)
                else:
                    self.agente.epsilon=1.0
                    action,nn=self.agente.act(s)

                s_, r, d, info = self.environment.step(action)

                if (abs(1/(math.e**(s_[1]+0.0)))**2)>1.1 or (abs(1/(math.e**(s_[1]+0.0)))**2)<0.9:
                    r=-1-abs(1-(1/(math.e**(s_[1].astype(float)+0.08))))
                else:
                    r=1

                r=float(r)

                if info['score']!=last_score:
                    biased=9
                    last_score=info['score']
                else:
                    biased=0
                r+=biased
                #self.environment.render()
                rwd+=r

                if nn:
                    rwd_nn+=r

                state=tf.convert_to_tensor([s],dtype=tf.float32)
                state_=tf.convert_to_tensor([s_],dtype=tf.float32)
                self.agente.update_mem(state, action, r, state_, d)

                if step_num%self.t_steps==0 and step_num>1:
                    if normal:
                        q_max,loss_t=self.agente.train_simple()
                        weight_updates+=1
                        # loss.append(float(loss_t))
                        # maxq.append(float(q_max))
                        # eoe_loss.append(float(loss_t))
                        # eoe_maxq.append(float(q_max))
                s=s_

                if normal:
                    if weight_updates%self.t_updates==0 and  weight_updates>0:
                        self.agente.target_net.set_weights(self.agente.q_net.get_weights())
            print("[",name,"]Training Episode ",episode," of ",self.max_episodes)

            if normal:
                avg_r_nn.append(sum(Rtrn_nn)/len(Rtrn_nn))

            eoe_avg_r.append(sum(eoe_Rtrn)/len(eoe_Rtrn))
            avg_r.append(sum(Rtrn)/len(Rtrn))
            self.save_data(TEMP_PATH,name,avg_r,eoe_avg_r,avg_r_nn)

        self.agente.q_net.save(POLICIES_PATH+"/"+name)

    def load_params(self,path):
        with open(r''+path+"/"+self.experiment_name+"_conf.yaml") as parameters:
            config_list = yaml.safe_load(parameters)
        #HYPERPARAMETERS
        mini_batch_size=config_list['training']['mini_batch_size']
        n_actions=config_list['training']['num_actions']
        learning_rate=config_list['training']['learning_rate']
        max_episodes=config_list['training']['num_episodes']
        max_epochs=config_list['training']['num_epochs']
        max_e=config_list['epsilon']['max_epsilon']
        max_steps=config_list['rl']['max_steps_per_episode']
        max_queue_length=config_list['rl']['max_queue_length']
        min_e=config_list['epsilon']['min_epsilon']
        e_decay=config_list['epsilon']['decay_epsilon']
        w_updates=config_list['training']['weight_updates']
        t_steps=config_list['training']['train_steps']
        t_updates=config_list['rl']['target_update_episodes']
        return n_actions,max_epochs,max_episodes,max_steps,max_e,min_e,e_decay,w_updates,t_updates,t_steps,mini_batch_size,max_queue_length    
           
    def save_data(self,path,name,avg_r,avg_maxq, avg_loss):
        with open(r''+path+"/"+name+'.yaml', 'w') as outfile:
                           data={'avr_r':avg_r}
                           yaml.dump(data, outfile, default_flow_style=False)
        return

if __name__ == "__main__":
    print("Training FlappyBirds environment with DQL")
    env=DQL()
    #env.episode_training("random")
    env.episode_training("qdl")
    pygame.quit()
# Out:
# Training FlappyBirds environment with DQL
# Flappy Bird Training
# Episode training  dql
# [ dql_episodes ]Training Episode  1  of  2000
# [ dql_episodes ]Training Episode  2  of  2000
# [ dql_episodes ]Training Episode  3  of  2000
# [ dql_episodes ]Training Episode  4  of  2000
# [ dql_episodes ]Training Episode  5  of  2000
# [ dql_episodes ]Training Episode  6  of  2000
# [ dql_episodes ]Training Episode  7  of  2000
# [ dql_episodes ]Training Episode  8  of  2000
# [ dql_episodes ]Training Episode  9  of  2000
# [ dql_episodes ]Training Episode  10  of  2000
# [ dql_episodes ]Training Episode  11  of  2000
# [ dql_episodes ]Training Episode  12  of  2000
# [ dql_episodes ]Training Episode  13  of  2000
# [ dql_episodes ]Training Episode  14  of  2000
# [ dql_episodes ]Training Episode  15  of  2000
# [ dql_episodes ]Training Episode  16  of  2000
# [ dql_episodes ]Training Episode  17  of  2000
# [ dql_episodes ]Training Episode  18  of  2000
# [ dql_episodes ]Training Episode  19  of  2000
# [ dql_episodes ]Training Episode  20  of  2000
# [ dql_episodes ]Training Episode  21  of  2000
# [ dql_episodes ]Training Episode  22  of  2000
# [ dql_episodes ]Training Episode  23  of  2000
# [ dql_episodes ]Training Episode  24  of  2000
# [ dql_episodes ]Training Episode  25  of  2000
# [ dql_episodes ]Training Episode  26  of  2000
# [ dql_episodes ]Training Episode  27  of  2000
# [ dql_episodes ]Training Episode  28  of  2000
# [ dql_episodes ]Training Episode  29  of  2000
# [ dql_episodes ]Training Episode  30  of  2000
# [ dql_episodes ]Training Episode  31  of  2000
# [ dql_episodes ]Training Episode  32  of  2000
# [ dql_episodes ]Training Episode  33  of  2000
# [ dql_episodes ]Training Episode  34  of  2000
# [ dql_episodes ]Training Episode  35  of  2000
# [ dql_episodes ]Training Episode  36  of  2000
# [ dql_episodes ]Training Episode  37  of  2000
# [ dql_episodes ]Training Episode  38  of  2000
# [ dql_episodes ]Training Episode  39  of  2000
# [ dql_episodes ]Training Episode  40  of  2000
# [ dql_episodes ]Training Episode  41  of  2000
# [ dql_episodes ]Training Episode  42  of  2000
# [ dql_episodes ]Training Episode  43  of  2000
# [ dql_episodes ]Training Episode  44  of  2000
# [ dql_episodes ]Training Episode  45  of  2000
# [ dql_episodes ]Training Episode  46  of  2000
# [ dql_episodes ]Training Episode  47  of  2000
# [ dql_episodes ]Training Episode  48  of  2000
# [ dql_episodes ]Training Episode  49  of  2000
# [ dql_episodes ]Training Episode  50  of  2000
# [ dql_episodes ]Training Episode  51  of  2000
# [ dql_episodes ]Training Episode  52  of  2000
# [ dql_episodes ]Training Episode  53  of  2000
# [ dql_episodes ]Training Episode  54  of  2000
# [ dql_episodes ]Training Episode  55  of  2000
# [ dql_episodes ]Training Episode  56  of  2000
# [ dql_episodes ]Training Episode  57  of  2000
# [ dql_episodes ]Training Episode  58  of  2000
# [ dql_episodes ]Training Episode  59  of  2000
# [ dql_episodes ]Training Episode  60  of  2000
# [ dql_episodes ]Training Episode  61  of  2000
# [ dql_episodes ]Training Episode  62  of  2000
# [ dql_episodes ]Training Episode  63  of  2000
# [ dql_episodes ]Training Episode  64  of  2000
# [ dql_episodes ]Training Episode  65  of  2000
# [ dql_episodes ]Training Episode  66  of  2000
# [ dql_episodes ]Training Episode  67  of  2000
# [ dql_episodes ]Training Episode  68  of  2000
# [ dql_episodes ]Training Episode  69  of  2000
# [ dql_episodes ]Training Episode  70  of  2000
# [ dql_episodes ]Training Episode  71  of  2000
# [ dql_episodes ]Training Episode  72  of  2000
# [ dql_episodes ]Training Episode  73  of  2000
# [ dql_episodes ]Training Episode  74  of  2000
# [ dql_episodes ]Training Episode  75  of  2000
# [ dql_episodes ]Training Episode  76  of  2000
# [ dql_episodes ]Training Episode  77  of  2000
# [ dql_episodes ]Training Episode  78  of  2000
# [ dql_episodes ]Training Episode  79  of  2000
# [ dql_episodes ]Training Episode  80  of  2000
# [ dql_episodes ]Training Episode  81  of  2000
# [ dql_episodes ]Training Episode  82  of  2000
# [ dql_episodes ]Training Episode  83  of  2000
# [ dql_episodes ]Training Episode  84  of  2000
# [ dql_episodes ]Training Episode  85  of  2000
# [ dql_episodes ]Training Episode  86  of  2000
# [ dql_episodes ]Training Episode  87  of  2000
# [ dql_episodes ]Training Episode  88  of  2000
# [ dql_episodes ]Training Episode  89  of  2000
# [ dql_episodes ]Training Episode  90  of  2000
# [ dql_episodes ]Training Episode  91  of  2000
# [ dql_episodes ]Training Episode  92  of  2000
# [ dql_episodes ]Training Episode  93  of  2000
# [ dql_episodes ]Training Episode  94  of  2000
# [ dql_episodes ]Training Episode  95  of  2000
# [ dql_episodes ]Training Episode  96  of  2000
# [ dql_episodes ]Training Episode  97  of  2000
# [ dql_episodes ]Training Episode  98  of  2000
# [ dql_episodes ]Training Episode  99  of  2000
# [ dql_episodes ]Training Episode  100  of  2000
# [ dql_episodes ]Training Episode  101  of  2000
# [ dql_episodes ]Training Episode  102  of  2000
# [ dql_episodes ]Training Episode  103  of  2000
# [ dql_episodes ]Training Episode  104  of  2000
# [ dql_episodes ]Training Episode  105  of  2000
# [ dql_episodes ]Training Episode  106  of  2000
# [ dql_episodes ]Training Episode  107  of  2000
# [ dql_episodes ]Training Episode  108  of  2000
# [ dql_episodes ]Training Episode  109  of  2000
# [ dql_episodes ]Training Episode  110  of  2000
# [ dql_episodes ]Training Episode  111  of  2000
# [ dql_episodes ]Training Episode  112  of  2000
# [ dql_episodes ]Training Episode  113  of  2000
# [ dql_episodes ]Training Episode  114  of  2000
# [ dql_episodes ]Training Episode  115  of  2000
# [ dql_episodes ]Training Episode  116  of  2000
# [ dql_episodes ]Training Episode  117  of  2000
# [ dql_episodes ]Training Episode  118  of  2000
# [ dql_episodes ]Training Episode  119  of  2000
# [ dql_episodes ]Training Episode  120  of  2000
# [ dql_episodes ]Training Episode  121  of  2000
# [ dql_episodes ]Training Episode  122  of  2000
# [ dql_episodes ]Training Episode  123  of  2000
# [ dql_episodes ]Training Episode  124  of  2000
# [ dql_episodes ]Training Episode  125  of  2000
# [ dql_episodes ]Training Episode  126  of  2000
# [ dql_episodes ]Training Episode  127  of  2000
# [ dql_episodes ]Training Episode  128  of  2000
# [ dql_episodes ]Training Episode  129  of  2000
# [ dql_episodes ]Training Episode  130  of  2000
# [ dql_episodes ]Training Episode  131  of  2000
# [ dql_episodes ]Training Episode  132  of  2000
# [ dql_episodes ]Training Episode  133  of  2000
# [ dql_episodes ]Training Episode  134  of  2000
# [ dql_episodes ]Training Episode  135  of  2000
# [ dql_episodes ]Training Episode  136  of  2000
# [ dql_episodes ]Training Episode  137  of  2000
# [ dql_episodes ]Training Episode  138  of  2000
# [ dql_episodes ]Training Episode  139  of  2000
# [ dql_episodes ]Training Episode  140  of  2000
# [ dql_episodes ]Training Episode  141  of  2000
# [ dql_episodes ]Training Episode  142  of  2000
# [ dql_episodes ]Training Episode  143  of  2000
# [ dql_episodes ]Training Episode  144  of  2000
# [ dql_episodes ]Training Episode  145  of  2000
# [ dql_episodes ]Training Episode  146  of  2000
# [ dql_episodes ]Training Episode  147  of  2000
# [ dql_episodes ]Training Episode  148  of  2000
# [ dql_episodes ]Training Episode  149  of  2000
# [ dql_episodes ]Training Episode  150  of  2000
# [ dql_episodes ]Training Episode  151  of  2000
# [ dql_episodes ]Training Episode  152  of  2000
# [ dql_episodes ]Training Episode  153  of  2000
# [ dql_episodes ]Training Episode  154  of  2000
# [ dql_episodes ]Training Episode  155  of  2000
# [ dql_episodes ]Training Episode  156  of  2000
# [ dql_episodes ]Training Episode  157  of  2000
# [ dql_episodes ]Training Episode  158  of  2000
# [ dql_episodes ]Training Episode  159  of  2000
# [ dql_episodes ]Training Episode  160  of  2000
# [ dql_episodes ]Training Episode  161  of  2000
# [ dql_episodes ]Training Episode  162  of  2000
# [ dql_episodes ]Training Episode  163  of  2000
# [ dql_episodes ]Training Episode  164  of  2000
# [ dql_episodes ]Training Episode  165  of  2000
# [ dql_episodes ]Training Episode  166  of  2000
# [ dql_episodes ]Training Episode  167  of  2000
# [ dql_episodes ]Training Episode  168  of  2000
# [ dql_episodes ]Training Episode  169  of  2000
# [ dql_episodes ]Training Episode  170  of  2000
# [ dql_episodes ]Training Episode  171  of  2000
# [ dql_episodes ]Training Episode  172  of  2000
# [ dql_episodes ]Training Episode  173  of  2000
# [ dql_episodes ]Training Episode  174  of  2000
# [ dql_episodes ]Training Episode  175  of  2000
# [ dql_episodes ]Training Episode  176  of  2000
# [ dql_episodes ]Training Episode  177  of  2000
# [ dql_episodes ]Training Episode  178  of  2000
# [ dql_episodes ]Training Episode  179  of  2000
# [ dql_episodes ]Training Episode  180  of  2000
# [ dql_episodes ]Training Episode  181  of  2000
# [ dql_episodes ]Training Episode  182  of  2000
# [ dql_episodes ]Training Episode  183  of  2000
# [ dql_episodes ]Training Episode  184  of  2000
# [ dql_episodes ]Training Episode  185  of  2000
# [ dql_episodes ]Training Episode  186  of  2000
# [ dql_episodes ]Training Episode  187  of  2000
# [ dql_episodes ]Training Episode  188  of  2000
# [ dql_episodes ]Training Episode  189  of  2000
# [ dql_episodes ]Training Episode  190  of  2000
# [ dql_episodes ]Training Episode  191  of  2000
# [ dql_episodes ]Training Episode  192  of  2000
# [ dql_episodes ]Training Episode  193  of  2000
# [ dql_episodes ]Training Episode  194  of  2000
# [ dql_episodes ]Training Episode  195  of  2000
# [ dql_episodes ]Training Episode  196  of  2000
# [ dql_episodes ]Training Episode  197  of  2000
# [ dql_episodes ]Training Episode  198  of  2000
# [ dql_episodes ]Training Episode  199  of  2000
# [ dql_episodes ]Training Episode  200  of  2000
# [ dql_episodes ]Training Episode  201  of  2000
# [ dql_episodes ]Training Episode  202  of  2000
# [ dql_episodes ]Training Episode  203  of  2000
# [ dql_episodes ]Training Episode  204  of  2000
# [ dql_episodes ]Training Episode  205  of  2000
# [ dql_episodes ]Training Episode  206  of  2000
# [ dql_episodes ]Training Episode  207  of  2000
# [ dql_episodes ]Training Episode  208  of  2000
# [ dql_episodes ]Training Episode  209  of  2000
# [ dql_episodes ]Training Episode  210  of  2000
# [ dql_episodes ]Training Episode  211  of  2000
# [ dql_episodes ]Training Episode  212  of  2000
# [ dql_episodes ]Training Episode  213  of  2000
# [ dql_episodes ]Training Episode  214  of  2000
# [ dql_episodes ]Training Episode  215  of  2000
# [ dql_episodes ]Training Episode  216  of  2000
# [ dql_episodes ]Training Episode  217  of  2000
# [ dql_episodes ]Training Episode  218  of  2000
# [ dql_episodes ]Training Episode  219  of  2000
# [ dql_episodes ]Training Episode  220  of  2000
# [ dql_episodes ]Training Episode  221  of  2000
# [ dql_episodes ]Training Episode  222  of  2000
# [ dql_episodes ]Training Episode  223  of  2000
# [ dql_episodes ]Training Episode  224  of  2000
# [ dql_episodes ]Training Episode  225  of  2000
# [ dql_episodes ]Training Episode  226  of  2000
# [ dql_episodes ]Training Episode  227  of  2000
# [ dql_episodes ]Training Episode  228  of  2000
# [ dql_episodes ]Training Episode  229  of  2000
# [ dql_episodes ]Training Episode  230  of  2000
# [ dql_episodes ]Training Episode  231  of  2000
# [ dql_episodes ]Training Episode  232  of  2000
# [ dql_episodes ]Training Episode  233  of  2000
# [ dql_episodes ]Training Episode  234  of  2000
# [ dql_episodes ]Training Episode  235  of  2000
# [ dql_episodes ]Training Episode  236  of  2000
# [ dql_episodes ]Training Episode  237  of  2000
# [ dql_episodes ]Training Episode  238  of  2000
# [ dql_episodes ]Training Episode  239  of  2000
# [ dql_episodes ]Training Episode  240  of  2000
# [ dql_episodes ]Training Episode  241  of  2000
# [ dql_episodes ]Training Episode  242  of  2000
# [ dql_episodes ]Training Episode  243  of  2000
# [ dql_episodes ]Training Episode  244  of  2000
# [ dql_episodes ]Training Episode  245  of  2000
# [ dql_episodes ]Training Episode  246  of  2000
# [ dql_episodes ]Training Episode  247  of  2000
# [ dql_episodes ]Training Episode  248  of  2000
# [ dql_episodes ]Training Episode  249  of  2000
# [ dql_episodes ]Training Episode  250  of  2000
# [ dql_episodes ]Training Episode  251  of  2000
# [ dql_episodes ]Training Episode  252  of  2000
# [ dql_episodes ]Training Episode  253  of  2000
# [ dql_episodes ]Training Episode  254  of  2000
# [ dql_episodes ]Training Episode  255  of  2000
# [ dql_episodes ]Training Episode  256  of  2000
# [ dql_episodes ]Training Episode  257  of  2000
# [ dql_episodes ]Training Episode  258  of  2000
# [ dql_episodes ]Training Episode  259  of  2000
# [ dql_episodes ]Training Episode  260  of  2000
# [ dql_episodes ]Training Episode  261  of  2000
# [ dql_episodes ]Training Episode  262  of  2000
# [ dql_episodes ]Training Episode  263  of  2000
# [ dql_episodes ]Training Episode  264  of  2000
# [ dql_episodes ]Training Episode  265  of  2000
# [ dql_episodes ]Training Episode  266  of  2000
# [ dql_episodes ]Training Episode  267  of  2000
# [ dql_episodes ]Training Episode  268  of  2000
# [ dql_episodes ]Training Episode  269  of  2000
# [ dql_episodes ]Training Episode  270  of  2000
# [ dql_episodes ]Training Episode  271  of  2000
# [ dql_episodes ]Training Episode  272  of  2000
# [ dql_episodes ]Training Episode  273  of  2000
# [ dql_episodes ]Training Episode  274  of  2000
# [ dql_episodes ]Training Episode  275  of  2000
# [ dql_episodes ]Training Episode  276  of  2000
# [ dql_episodes ]Training Episode  277  of  2000
# [ dql_episodes ]Training Episode  278  of  2000
# [ dql_episodes ]Training Episode  279  of  2000
# [ dql_episodes ]Training Episode  280  of  2000
# [ dql_episodes ]Training Episode  281  of  2000
# [ dql_episodes ]Training Episode  282  of  2000
# [ dql_episodes ]Training Episode  283  of  2000
# [ dql_episodes ]Training Episode  284  of  2000
# [ dql_episodes ]Training Episode  285  of  2000
# [ dql_episodes ]Training Episode  286  of  2000
# [ dql_episodes ]Training Episode  287  of  2000
# [ dql_episodes ]Training Episode  288  of  2000
# [ dql_episodes ]Training Episode  289  of  2000
# [ dql_episodes ]Training Episode  290  of  2000
# [ dql_episodes ]Training Episode  291  of  2000
# [ dql_episodes ]Training Episode  292  of  2000
# [ dql_episodes ]Training Episode  293  of  2000
# [ dql_episodes ]Training Episode  294  of  2000
# [ dql_episodes ]Training Episode  295  of  2000
# [ dql_episodes ]Training Episode  296  of  2000
# [ dql_episodes ]Training Episode  297  of  2000
# [ dql_episodes ]Training Episode  298  of  2000
# [ dql_episodes ]Training Episode  299  of  2000
# [ dql_episodes ]Training Episode  300  of  2000
# [ dql_episodes ]Training Episode  301  of  2000
# [ dql_episodes ]Training Episode  302  of  2000
# [ dql_episodes ]Training Episode  303  of  2000
# [ dql_episodes ]Training Episode  304  of  2000
# [ dql_episodes ]Training Episode  305  of  2000
# [ dql_episodes ]Training Episode  306  of  2000
# [ dql_episodes ]Training Episode  307  of  2000
# [ dql_episodes ]Training Episode  308  of  2000
# [ dql_episodes ]Training Episode  309  of  2000
# [ dql_episodes ]Training Episode  310  of  2000
# [ dql_episodes ]Training Episode  311  of  2000
# [ dql_episodes ]Training Episode  312  of  2000
# [ dql_episodes ]Training Episode  313  of  2000
# [ dql_episodes ]Training Episode  314  of  2000
# [ dql_episodes ]Training Episode  315  of  2000
# [ dql_episodes ]Training Episode  316  of  2000
# [ dql_episodes ]Training Episode  317  of  2000
# [ dql_episodes ]Training Episode  318  of  2000
# [ dql_episodes ]Training Episode  319  of  2000
# [ dql_episodes ]Training Episode  320  of  2000
# [ dql_episodes ]Training Episode  321  of  2000
# [ dql_episodes ]Training Episode  322  of  2000
# [ dql_episodes ]Training Episode  323  of  2000
# [ dql_episodes ]Training Episode  324  of  2000
# [ dql_episodes ]Training Episode  325  of  2000
# [ dql_episodes ]Training Episode  326  of  2000
# [ dql_episodes ]Training Episode  327  of  2000
# [ dql_episodes ]Training Episode  328  of  2000
# [ dql_episodes ]Training Episode  329  of  2000
# [ dql_episodes ]Training Episode  330  of  2000
# [ dql_episodes ]Training Episode  331  of  2000
# [ dql_episodes ]Training Episode  332  of  2000
# [ dql_episodes ]Training Episode  333  of  2000
# [ dql_episodes ]Training Episode  334  of  2000
# [ dql_episodes ]Training Episode  335  of  2000
# [ dql_episodes ]Training Episode  336  of  2000
# [ dql_episodes ]Training Episode  337  of  2000
# [ dql_episodes ]Training Episode  338  of  2000
# [ dql_episodes ]Training Episode  339  of  2000
# [ dql_episodes ]Training Episode  340  of  2000
# [ dql_episodes ]Training Episode  341  of  2000
# [ dql_episodes ]Training Episode  342  of  2000
# [ dql_episodes ]Training Episode  343  of  2000
# [ dql_episodes ]Training Episode  344  of  2000
# [ dql_episodes ]Training Episode  345  of  2000
# [ dql_episodes ]Training Episode  346  of  2000
# [ dql_episodes ]Training Episode  347  of  2000
# [ dql_episodes ]Training Episode  348  of  2000
# [ dql_episodes ]Training Episode  349  of  2000
# [ dql_episodes ]Training Episode  350  of  2000
# [ dql_episodes ]Training Episode  351  of  2000
# [ dql_episodes ]Training Episode  352  of  2000
# [ dql_episodes ]Training Episode  353  of  2000
# [ dql_episodes ]Training Episode  354  of  2000
# [ dql_episodes ]Training Episode  355  of  2000
# [ dql_episodes ]Training Episode  356  of  2000
# [ dql_episodes ]Training Episode  357  of  2000
# [ dql_episodes ]Training Episode  358  of  2000
# [ dql_episodes ]Training Episode  359  of  2000
# [ dql_episodes ]Training Episode  360  of  2000
# [ dql_episodes ]Training Episode  361  of  2000
# [ dql_episodes ]Training Episode  362  of  2000
# [ dql_episodes ]Training Episode  363  of  2000
# [ dql_episodes ]Training Episode  364  of  2000
# [ dql_episodes ]Training Episode  365  of  2000
# [ dql_episodes ]Training Episode  366  of  2000
# [ dql_episodes ]Training Episode  367  of  2000
# [ dql_episodes ]Training Episode  368  of  2000
# [ dql_episodes ]Training Episode  369  of  2000
# [ dql_episodes ]Training Episode  370  of  2000
# [ dql_episodes ]Training Episode  371  of  2000
# [ dql_episodes ]Training Episode  372  of  2000
# [ dql_episodes ]Training Episode  373  of  2000
# [ dql_episodes ]Training Episode  374  of  2000
# [ dql_episodes ]Training Episode  375  of  2000
# [ dql_episodes ]Training Episode  376  of  2000
# [ dql_episodes ]Training Episode  377  of  2000
# [ dql_episodes ]Training Episode  378  of  2000
# [ dql_episodes ]Training Episode  379  of  2000
# [ dql_episodes ]Training Episode  380  of  2000
# [ dql_episodes ]Training Episode  381  of  2000
# [ dql_episodes ]Training Episode  382  of  2000
# [ dql_episodes ]Training Episode  383  of  2000
# [ dql_episodes ]Training Episode  384  of  2000
# [ dql_episodes ]Training Episode  385  of  2000
# [ dql_episodes ]Training Episode  386  of  2000
# [ dql_episodes ]Training Episode  387  of  2000
# [ dql_episodes ]Training Episode  388  of  2000
# [ dql_episodes ]Training Episode  389  of  2000
# [ dql_episodes ]Training Episode  390  of  2000
# [ dql_episodes ]Training Episode  391  of  2000
# [ dql_episodes ]Training Episode  392  of  2000
# [ dql_episodes ]Training Episode  393  of  2000
# [ dql_episodes ]Training Episode  394  of  2000
# [ dql_episodes ]Training Episode  395  of  2000
# [ dql_episodes ]Training Episode  396  of  2000
# [ dql_episodes ]Training Episode  397  of  2000
# [ dql_episodes ]Training Episode  398  of  2000
# [ dql_episodes ]Training Episode  399  of  2000
# [ dql_episodes ]Training Episode  400  of  2000
# [ dql_episodes ]Training Episode  401  of  2000
# [ dql_episodes ]Training Episode  402  of  2000
# [ dql_episodes ]Training Episode  403  of  2000
# [ dql_episodes ]Training Episode  404  of  2000
# [ dql_episodes ]Training Episode  405  of  2000
# [ dql_episodes ]Training Episode  406  of  2000
# [ dql_episodes ]Training Episode  407  of  2000
# [ dql_episodes ]Training Episode  408  of  2000
# [ dql_episodes ]Training Episode  409  of  2000
# [ dql_episodes ]Training Episode  410  of  2000
# [ dql_episodes ]Training Episode  411  of  2000
# [ dql_episodes ]Training Episode  412  of  2000
# [ dql_episodes ]Training Episode  413  of  2000
# [ dql_episodes ]Training Episode  414  of  2000
# [ dql_episodes ]Training Episode  415  of  2000
# [ dql_episodes ]Training Episode  416  of  2000
# [ dql_episodes ]Training Episode  417  of  2000
# [ dql_episodes ]Training Episode  418  of  2000
# [ dql_episodes ]Training Episode  419  of  2000
# [ dql_episodes ]Training Episode  420  of  2000
# [ dql_episodes ]Training Episode  421  of  2000
# [ dql_episodes ]Training Episode  422  of  2000
# [ dql_episodes ]Training Episode  423  of  2000
# [ dql_episodes ]Training Episode  424  of  2000
# [ dql_episodes ]Training Episode  425  of  2000
# [ dql_episodes ]Training Episode  426  of  2000
# [ dql_episodes ]Training Episode  427  of  2000
# [ dql_episodes ]Training Episode  428  of  2000
# [ dql_episodes ]Training Episode  429  of  2000
# [ dql_episodes ]Training Episode  430  of  2000
# [ dql_episodes ]Training Episode  431  of  2000
# [ dql_episodes ]Training Episode  432  of  2000
# [ dql_episodes ]Training Episode  433  of  2000
# [ dql_episodes ]Training Episode  434  of  2000
# [ dql_episodes ]Training Episode  435  of  2000
# [ dql_episodes ]Training Episode  436  of  2000
# [ dql_episodes ]Training Episode  437  of  2000
# [ dql_episodes ]Training Episode  438  of  2000
# [ dql_episodes ]Training Episode  439  of  2000
# [ dql_episodes ]Training Episode  440  of  2000
# [ dql_episodes ]Training Episode  441  of  2000
# [ dql_episodes ]Training Episode  442  of  2000
# [ dql_episodes ]Training Episode  443  of  2000
# [ dql_episodes ]Training Episode  444  of  2000
# [ dql_episodes ]Training Episode  445  of  2000
# [ dql_episodes ]Training Episode  446  of  2000
# [ dql_episodes ]Training Episode  447  of  2000
# [ dql_episodes ]Training Episode  448  of  2000
# [ dql_episodes ]Training Episode  449  of  2000
# [ dql_episodes ]Training Episode  450  of  2000
# [ dql_episodes ]Training Episode  451  of  2000
# [ dql_episodes ]Training Episode  452  of  2000
# [ dql_episodes ]Training Episode  453  of  2000
# [ dql_episodes ]Training Episode  454  of  2000
# [ dql_episodes ]Training Episode  455  of  2000
# [ dql_episodes ]Training Episode  456  of  2000
# [ dql_episodes ]Training Episode  457  of  2000
# [ dql_episodes ]Training Episode  458  of  2000
# [ dql_episodes ]Training Episode  459  of  2000
# [ dql_episodes ]Training Episode  460  of  2000
# [ dql_episodes ]Training Episode  461  of  2000
# [ dql_episodes ]Training Episode  462  of  2000
# [ dql_episodes ]Training Episode  463  of  2000
# [ dql_episodes ]Training Episode  464  of  2000
# [ dql_episodes ]Training Episode  465  of  2000
# [ dql_episodes ]Training Episode  466  of  2000
# [ dql_episodes ]Training Episode  467  of  2000
# [ dql_episodes ]Training Episode  468  of  2000
# [ dql_episodes ]Training Episode  469  of  2000
# [ dql_episodes ]Training Episode  470  of  2000
# [ dql_episodes ]Training Episode  471  of  2000
# [ dql_episodes ]Training Episode  472  of  2000
# [ dql_episodes ]Training Episode  473  of  2000
# [ dql_episodes ]Training Episode  474  of  2000
# [ dql_episodes ]Training Episode  475  of  2000
# [ dql_episodes ]Training Episode  476  of  2000
# [ dql_episodes ]Training Episode  477  of  2000
# [ dql_episodes ]Training Episode  478  of  2000
# [ dql_episodes ]Training Episode  479  of  2000
# [ dql_episodes ]Training Episode  480  of  2000
# [ dql_episodes ]Training Episode  481  of  2000
# [ dql_episodes ]Training Episode  482  of  2000
# [ dql_episodes ]Training Episode  483  of  2000
# [ dql_episodes ]Training Episode  484  of  2000
# [ dql_episodes ]Training Episode  485  of  2000
# [ dql_episodes ]Training Episode  486  of  2000
# [ dql_episodes ]Training Episode  487  of  2000
# [ dql_episodes ]Training Episode  488  of  2000
# [ dql_episodes ]Training Episode  489  of  2000
# [ dql_episodes ]Training Episode  490  of  2000
# [ dql_episodes ]Training Episode  491  of  2000
# [ dql_episodes ]Training Episode  492  of  2000
# [ dql_episodes ]Training Episode  493  of  2000
# [ dql_episodes ]Training Episode  494  of  2000
# [ dql_episodes ]Training Episode  495  of  2000
# [ dql_episodes ]Training Episode  496  of  2000
# [ dql_episodes ]Training Episode  497  of  2000
# [ dql_episodes ]Training Episode  498  of  2000
# [ dql_episodes ]Training Episode  499  of  2000
# [ dql_episodes ]Training Episode  500  of  2000
# [ dql_episodes ]Training Episode  501  of  2000
# [ dql_episodes ]Training Episode  502  of  2000
# [ dql_episodes ]Training Episode  503  of  2000
# [ dql_episodes ]Training Episode  504  of  2000
# [ dql_episodes ]Training Episode  505  of  2000
# [ dql_episodes ]Training Episode  506  of  2000
# [ dql_episodes ]Training Episode  507  of  2000
# [ dql_episodes ]Training Episode  508  of  2000
# [ dql_episodes ]Training Episode  509  of  2000
# [ dql_episodes ]Training Episode  510  of  2000
# [ dql_episodes ]Training Episode  511  of  2000
# [ dql_episodes ]Training Episode  512  of  2000
# [ dql_episodes ]Training Episode  513  of  2000
# [ dql_episodes ]Training Episode  514  of  2000
# [ dql_episodes ]Training Episode  515  of  2000
# [ dql_episodes ]Training Episode  516  of  2000
# [ dql_episodes ]Training Episode  517  of  2000
# [ dql_episodes ]Training Episode  518  of  2000
# [ dql_episodes ]Training Episode  519  of  2000
# [ dql_episodes ]Training Episode  520  of  2000
# [ dql_episodes ]Training Episode  521  of  2000
# [ dql_episodes ]Training Episode  522  of  2000
# [ dql_episodes ]Training Episode  523  of  2000
# [ dql_episodes ]Training Episode  524  of  2000
# [ dql_episodes ]Training Episode  525  of  2000
# [ dql_episodes ]Training Episode  526  of  2000
# [ dql_episodes ]Training Episode  527  of  2000
# [ dql_episodes ]Training Episode  528  of  2000
# [ dql_episodes ]Training Episode  529  of  2000
# [ dql_episodes ]Training Episode  530  of  2000
# [ dql_episodes ]Training Episode  531  of  2000
# [ dql_episodes ]Training Episode  532  of  2000
# [ dql_episodes ]Training Episode  533  of  2000
# [ dql_episodes ]Training Episode  534  of  2000
# [ dql_episodes ]Training Episode  535  of  2000
# [ dql_episodes ]Training Episode  536  of  2000
# [ dql_episodes ]Training Episode  537  of  2000
# [ dql_episodes ]Training Episode  538  of  2000
# [ dql_episodes ]Training Episode  539  of  2000
# [ dql_episodes ]Training Episode  540  of  2000
# [ dql_episodes ]Training Episode  541  of  2000
# [ dql_episodes ]Training Episode  542  of  2000
# [ dql_episodes ]Training Episode  543  of  2000
# [ dql_episodes ]Training Episode  544  of  2000
# [ dql_episodes ]Training Episode  545  of  2000
# [ dql_episodes ]Training Episode  546  of  2000
# [ dql_episodes ]Training Episode  547  of  2000
# [ dql_episodes ]Training Episode  548  of  2000
# [ dql_episodes ]Training Episode  549  of  2000
# [ dql_episodes ]Training Episode  550  of  2000
# [ dql_episodes ]Training Episode  551  of  2000
# [ dql_episodes ]Training Episode  552  of  2000
# [ dql_episodes ]Training Episode  553  of  2000
# [ dql_episodes ]Training Episode  554  of  2000
# [ dql_episodes ]Training Episode  555  of  2000
# [ dql_episodes ]Training Episode  556  of  2000
# [ dql_episodes ]Training Episode  557  of  2000
# [ dql_episodes ]Training Episode  558  of  2000
# [ dql_episodes ]Training Episode  559  of  2000
# [ dql_episodes ]Training Episode  560  of  2000
# [ dql_episodes ]Training Episode  561  of  2000
# [ dql_episodes ]Training Episode  562  of  2000
# [ dql_episodes ]Training Episode  563  of  2000
# [ dql_episodes ]Training Episode  564  of  2000
# [ dql_episodes ]Training Episode  565  of  2000
# [ dql_episodes ]Training Episode  566  of  2000
# [ dql_episodes ]Training Episode  567  of  2000
# [ dql_episodes ]Training Episode  568  of  2000
# [ dql_episodes ]Training Episode  569  of  2000
# [ dql_episodes ]Training Episode  570  of  2000
# [ dql_episodes ]Training Episode  571  of  2000
# [ dql_episodes ]Training Episode  572  of  2000
# [ dql_episodes ]Training Episode  573  of  2000
# [ dql_episodes ]Training Episode  574  of  2000
# [ dql_episodes ]Training Episode  575  of  2000
# [ dql_episodes ]Training Episode  576  of  2000
# [ dql_episodes ]Training Episode  577  of  2000
# [ dql_episodes ]Training Episode  578  of  2000
# [ dql_episodes ]Training Episode  579  of  2000
# [ dql_episodes ]Training Episode  580  of  2000
# [ dql_episodes ]Training Episode  581  of  2000
# [ dql_episodes ]Training Episode  582  of  2000
# [ dql_episodes ]Training Episode  583  of  2000
# [ dql_episodes ]Training Episode  584  of  2000
# [ dql_episodes ]Training Episode  585  of  2000
# [ dql_episodes ]Training Episode  586  of  2000
# [ dql_episodes ]Training Episode  587  of  2000
# [ dql_episodes ]Training Episode  588  of  2000
# [ dql_episodes ]Training Episode  589  of  2000
# [ dql_episodes ]Training Episode  590  of  2000
# [ dql_episodes ]Training Episode  591  of  2000
# [ dql_episodes ]Training Episode  592  of  2000
# [ dql_episodes ]Training Episode  593  of  2000
# [ dql_episodes ]Training Episode  594  of  2000
# [ dql_episodes ]Training Episode  595  of  2000
# [ dql_episodes ]Training Episode  596  of  2000
# [ dql_episodes ]Training Episode  597  of  2000
# [ dql_episodes ]Training Episode  598  of  2000
# [ dql_episodes ]Training Episode  599  of  2000
# [ dql_episodes ]Training Episode  600  of  2000
# [ dql_episodes ]Training Episode  601  of  2000
# [ dql_episodes ]Training Episode  602  of  2000
# [ dql_episodes ]Training Episode  603  of  2000
# [ dql_episodes ]Training Episode  604  of  2000
# [ dql_episodes ]Training Episode  605  of  2000
# [ dql_episodes ]Training Episode  606  of  2000
# [ dql_episodes ]Training Episode  607  of  2000
# [ dql_episodes ]Training Episode  608  of  2000
# [ dql_episodes ]Training Episode  609  of  2000
# [ dql_episodes ]Training Episode  610  of  2000
# [ dql_episodes ]Training Episode  611  of  2000
# [ dql_episodes ]Training Episode  612  of  2000
# [ dql_episodes ]Training Episode  613  of  2000
# [ dql_episodes ]Training Episode  614  of  2000
# [ dql_episodes ]Training Episode  615  of  2000
# [ dql_episodes ]Training Episode  616  of  2000
# [ dql_episodes ]Training Episode  617  of  2000
# [ dql_episodes ]Training Episode  618  of  2000
# [ dql_episodes ]Training Episode  619  of  2000
# [ dql_episodes ]Training Episode  620  of  2000
# [ dql_episodes ]Training Episode  621  of  2000
# [ dql_episodes ]Training Episode  622  of  2000
# [ dql_episodes ]Training Episode  623  of  2000
# [ dql_episodes ]Training Episode  624  of  2000
# [ dql_episodes ]Training Episode  625  of  2000
# [ dql_episodes ]Training Episode  626  of  2000
# [ dql_episodes ]Training Episode  627  of  2000
# [ dql_episodes ]Training Episode  628  of  2000
# [ dql_episodes ]Training Episode  629  of  2000
# [ dql_episodes ]Training Episode  630  of  2000
# [ dql_episodes ]Training Episode  631  of  2000
# [ dql_episodes ]Training Episode  632  of  2000
# [ dql_episodes ]Training Episode  633  of  2000
# [ dql_episodes ]Training Episode  634  of  2000
# [ dql_episodes ]Training Episode  635  of  2000
# [ dql_episodes ]Training Episode  636  of  2000
# [ dql_episodes ]Training Episode  637  of  2000
# [ dql_episodes ]Training Episode  638  of  2000
# [ dql_episodes ]Training Episode  639  of  2000
# [ dql_episodes ]Training Episode  640  of  2000
# [ dql_episodes ]Training Episode  641  of  2000
# [ dql_episodes ]Training Episode  642  of  2000
# [ dql_episodes ]Training Episode  643  of  2000
# [ dql_episodes ]Training Episode  644  of  2000
# [ dql_episodes ]Training Episode  645  of  2000
# [ dql_episodes ]Training Episode  646  of  2000
# [ dql_episodes ]Training Episode  647  of  2000
# [ dql_episodes ]Training Episode  648  of  2000
# [ dql_episodes ]Training Episode  649  of  2000
# [ dql_episodes ]Training Episode  650  of  2000
# [ dql_episodes ]Training Episode  651  of  2000
# [ dql_episodes ]Training Episode  652  of  2000
# [ dql_episodes ]Training Episode  653  of  2000
# [ dql_episodes ]Training Episode  654  of  2000
# [ dql_episodes ]Training Episode  655  of  2000
# [ dql_episodes ]Training Episode  656  of  2000
# [ dql_episodes ]Training Episode  657  of  2000
# [ dql_episodes ]Training Episode  658  of  2000
# [ dql_episodes ]Training Episode  659  of  2000
# [ dql_episodes ]Training Episode  660  of  2000
# [ dql_episodes ]Training Episode  661  of  2000
# [ dql_episodes ]Training Episode  662  of  2000
# [ dql_episodes ]Training Episode  663  of  2000
# [ dql_episodes ]Training Episode  664  of  2000
# [ dql_episodes ]Training Episode  665  of  2000
# [ dql_episodes ]Training Episode  666  of  2000
# [ dql_episodes ]Training Episode  667  of  2000
# [ dql_episodes ]Training Episode  668  of  2000
# [ dql_episodes ]Training Episode  669  of  2000
# [ dql_episodes ]Training Episode  670  of  2000
# [ dql_episodes ]Training Episode  671  of  2000
# [ dql_episodes ]Training Episode  672  of  2000
# [ dql_episodes ]Training Episode  673  of  2000
# [ dql_episodes ]Training Episode  674  of  2000
# [ dql_episodes ]Training Episode  675  of  2000
# [ dql_episodes ]Training Episode  676  of  2000
# [ dql_episodes ]Training Episode  677  of  2000
# [ dql_episodes ]Training Episode  678  of  2000
# [ dql_episodes ]Training Episode  679  of  2000
# [ dql_episodes ]Training Episode  680  of  2000
# [ dql_episodes ]Training Episode  681  of  2000
# [ dql_episodes ]Training Episode  682  of  2000
# [ dql_episodes ]Training Episode  683  of  2000
# [ dql_episodes ]Training Episode  684  of  2000
# [ dql_episodes ]Training Episode  685  of  2000
# [ dql_episodes ]Training Episode  686  of  2000
# [ dql_episodes ]Training Episode  687  of  2000
# [ dql_episodes ]Training Episode  688  of  2000
# [ dql_episodes ]Training Episode  689  of  2000
# [ dql_episodes ]Training Episode  690  of  2000
# [ dql_episodes ]Training Episode  691  of  2000
# [ dql_episodes ]Training Episode  692  of  2000
# [ dql_episodes ]Training Episode  693  of  2000
# [ dql_episodes ]Training Episode  694  of  2000
# [ dql_episodes ]Training Episode  695  of  2000
# [ dql_episodes ]Training Episode  696  of  2000
# [ dql_episodes ]Training Episode  697  of  2000
# [ dql_episodes ]Training Episode  698  of  2000
# [ dql_episodes ]Training Episode  699  of  2000
# [ dql_episodes ]Training Episode  700  of  2000
# [ dql_episodes ]Training Episode  701  of  2000
# [ dql_episodes ]Training Episode  702  of  2000
# [ dql_episodes ]Training Episode  703  of  2000
# [ dql_episodes ]Training Episode  704  of  2000
# [ dql_episodes ]Training Episode  705  of  2000
# [ dql_episodes ]Training Episode  706  of  2000
# [ dql_episodes ]Training Episode  707  of  2000
# [ dql_episodes ]Training Episode  708  of  2000
# [ dql_episodes ]Training Episode  709  of  2000
# [ dql_episodes ]Training Episode  710  of  2000
# [ dql_episodes ]Training Episode  711  of  2000
# [ dql_episodes ]Training Episode  712  of  2000
# [ dql_episodes ]Training Episode  713  of  2000
# [ dql_episodes ]Training Episode  714  of  2000
# [ dql_episodes ]Training Episode  715  of  2000
# [ dql_episodes ]Training Episode  716  of  2000
# [ dql_episodes ]Training Episode  717  of  2000
# [ dql_episodes ]Training Episode  718  of  2000
# [ dql_episodes ]Training Episode  719  of  2000
# [ dql_episodes ]Training Episode  720  of  2000
# [ dql_episodes ]Training Episode  721  of  2000
# [ dql_episodes ]Training Episode  722  of  2000
# [ dql_episodes ]Training Episode  723  of  2000
# [ dql_episodes ]Training Episode  724  of  2000
# [ dql_episodes ]Training Episode  725  of  2000
# [ dql_episodes ]Training Episode  726  of  2000
# [ dql_episodes ]Training Episode  727  of  2000
# [ dql_episodes ]Training Episode  728  of  2000
# [ dql_episodes ]Training Episode  729  of  2000
# [ dql_episodes ]Training Episode  730  of  2000
# [ dql_episodes ]Training Episode  731  of  2000
# [ dql_episodes ]Training Episode  732  of  2000
# [ dql_episodes ]Training Episode  733  of  2000
# [ dql_episodes ]Training Episode  734  of  2000
# [ dql_episodes ]Training Episode  735  of  2000
# [ dql_episodes ]Training Episode  736  of  2000
# [ dql_episodes ]Training Episode  737  of  2000
# [ dql_episodes ]Training Episode  738  of  2000
# [ dql_episodes ]Training Episode  739  of  2000
# [ dql_episodes ]Training Episode  740  of  2000
# [ dql_episodes ]Training Episode  741  of  2000
# [ dql_episodes ]Training Episode  742  of  2000
# [ dql_episodes ]Training Episode  743  of  2000
# [ dql_episodes ]Training Episode  744  of  2000
# [ dql_episodes ]Training Episode  745  of  2000
# [ dql_episodes ]Training Episode  746  of  2000
# [ dql_episodes ]Training Episode  747  of  2000
# [ dql_episodes ]Training Episode  748  of  2000
# [ dql_episodes ]Training Episode  749  of  2000
# [ dql_episodes ]Training Episode  750  of  2000
# [ dql_episodes ]Training Episode  751  of  2000
# [ dql_episodes ]Training Episode  752  of  2000
# [ dql_episodes ]Training Episode  753  of  2000
# [ dql_episodes ]Training Episode  754  of  2000
# [ dql_episodes ]Training Episode  755  of  2000
# [ dql_episodes ]Training Episode  756  of  2000
# [ dql_episodes ]Training Episode  757  of  2000
# [ dql_episodes ]Training Episode  758  of  2000
# [ dql_episodes ]Training Episode  759  of  2000
# [ dql_episodes ]Training Episode  760  of  2000
# [ dql_episodes ]Training Episode  761  of  2000
# [ dql_episodes ]Training Episode  762  of  2000
# [ dql_episodes ]Training Episode  763  of  2000
# [ dql_episodes ]Training Episode  764  of  2000
# [ dql_episodes ]Training Episode  765  of  2000
# [ dql_episodes ]Training Episode  766  of  2000
# [ dql_episodes ]Training Episode  767  of  2000
# [ dql_episodes ]Training Episode  768  of  2000
# [ dql_episodes ]Training Episode  769  of  2000
# [ dql_episodes ]Training Episode  770  of  2000
# [ dql_episodes ]Training Episode  771  of  2000
# [ dql_episodes ]Training Episode  772  of  2000
# [ dql_episodes ]Training Episode  773  of  2000
# [ dql_episodes ]Training Episode  774  of  2000
# [ dql_episodes ]Training Episode  775  of  2000
# [ dql_episodes ]Training Episode  776  of  2000
# [ dql_episodes ]Training Episode  777  of  2000
# [ dql_episodes ]Training Episode  778  of  2000
# [ dql_episodes ]Training Episode  779  of  2000
# [ dql_episodes ]Training Episode  780  of  2000
# [ dql_episodes ]Training Episode  781  of  2000
# [ dql_episodes ]Training Episode  782  of  2000
# [ dql_episodes ]Training Episode  783  of  2000
# [ dql_episodes ]Training Episode  784  of  2000
# [ dql_episodes ]Training Episode  785  of  2000
# [ dql_episodes ]Training Episode  786  of  2000
# [ dql_episodes ]Training Episode  787  of  2000
# [ dql_episodes ]Training Episode  788  of  2000
# [ dql_episodes ]Training Episode  789  of  2000
# [ dql_episodes ]Training Episode  790  of  2000
# [ dql_episodes ]Training Episode  791  of  2000
# [ dql_episodes ]Training Episode  792  of  2000
# [ dql_episodes ]Training Episode  793  of  2000
# [ dql_episodes ]Training Episode  794  of  2000
# [ dql_episodes ]Training Episode  795  of  2000
# [ dql_episodes ]Training Episode  796  of  2000
# [ dql_episodes ]Training Episode  797  of  2000
# [ dql_episodes ]Training Episode  798  of  2000
# [ dql_episodes ]Training Episode  799  of  2000
# [ dql_episodes ]Training Episode  800  of  2000
# [ dql_episodes ]Training Episode  801  of  2000
# [ dql_episodes ]Training Episode  802  of  2000
# [ dql_episodes ]Training Episode  803  of  2000
# [ dql_episodes ]Training Episode  804  of  2000
# [ dql_episodes ]Training Episode  805  of  2000
# [ dql_episodes ]Training Episode  806  of  2000
# [ dql_episodes ]Training Episode  807  of  2000
# [ dql_episodes ]Training Episode  808  of  2000
# [ dql_episodes ]Training Episode  809  of  2000
# [ dql_episodes ]Training Episode  810  of  2000
# [ dql_episodes ]Training Episode  811  of  2000
# [ dql_episodes ]Training Episode  812  of  2000
# [ dql_episodes ]Training Episode  813  of  2000
# [ dql_episodes ]Training Episode  814  of  2000
# [ dql_episodes ]Training Episode  815  of  2000
# [ dql_episodes ]Training Episode  816  of  2000
# [ dql_episodes ]Training Episode  817  of  2000
# [ dql_episodes ]Training Episode  818  of  2000
# [ dql_episodes ]Training Episode  819  of  2000
# [ dql_episodes ]Training Episode  820  of  2000
# [ dql_episodes ]Training Episode  821  of  2000
# [ dql_episodes ]Training Episode  822  of  2000
# [ dql_episodes ]Training Episode  823  of  2000
# [ dql_episodes ]Training Episode  824  of  2000
# [ dql_episodes ]Training Episode  825  of  2000
# [ dql_episodes ]Training Episode  826  of  2000
# [ dql_episodes ]Training Episode  827  of  2000
# [ dql_episodes ]Training Episode  828  of  2000
# [ dql_episodes ]Training Episode  829  of  2000
# [ dql_episodes ]Training Episode  830  of  2000
# [ dql_episodes ]Training Episode  831  of  2000
# [ dql_episodes ]Training Episode  832  of  2000
# [ dql_episodes ]Training Episode  833  of  2000
# [ dql_episodes ]Training Episode  834  of  2000
# [ dql_episodes ]Training Episode  835  of  2000
# [ dql_episodes ]Training Episode  836  of  2000
# [ dql_episodes ]Training Episode  837  of  2000
# [ dql_episodes ]Training Episode  838  of  2000
# [ dql_episodes ]Training Episode  839  of  2000
# [ dql_episodes ]Training Episode  840  of  2000
# [ dql_episodes ]Training Episode  841  of  2000
# [ dql_episodes ]Training Episode  842  of  2000
# [ dql_episodes ]Training Episode  843  of  2000
# [ dql_episodes ]Training Episode  844  of  2000
# [ dql_episodes ]Training Episode  845  of  2000
# [ dql_episodes ]Training Episode  846  of  2000
# [ dql_episodes ]Training Episode  847  of  2000
# [ dql_episodes ]Training Episode  848  of  2000
# [ dql_episodes ]Training Episode  849  of  2000
# [ dql_episodes ]Training Episode  850  of  2000
# [ dql_episodes ]Training Episode  851  of  2000
# [ dql_episodes ]Training Episode  852  of  2000
# [ dql_episodes ]Training Episode  853  of  2000
# [ dql_episodes ]Training Episode  854  of  2000
# [ dql_episodes ]Training Episode  855  of  2000
# [ dql_episodes ]Training Episode  856  of  2000
# [ dql_episodes ]Training Episode  857  of  2000
# [ dql_episodes ]Training Episode  858  of  2000
# [ dql_episodes ]Training Episode  859  of  2000
# [ dql_episodes ]Training Episode  860  of  2000
# [ dql_episodes ]Training Episode  861  of  2000
# [ dql_episodes ]Training Episode  862  of  2000
# [ dql_episodes ]Training Episode  863  of  2000
# [ dql_episodes ]Training Episode  864  of  2000
# [ dql_episodes ]Training Episode  865  of  2000
# [ dql_episodes ]Training Episode  866  of  2000
# [ dql_episodes ]Training Episode  867  of  2000
# [ dql_episodes ]Training Episode  868  of  2000
# [ dql_episodes ]Training Episode  869  of  2000
# [ dql_episodes ]Training Episode  870  of  2000
# [ dql_episodes ]Training Episode  871  of  2000
# [ dql_episodes ]Training Episode  872  of  2000
# [ dql_episodes ]Training Episode  873  of  2000
# [ dql_episodes ]Training Episode  874  of  2000
# [ dql_episodes ]Training Episode  875  of  2000
# [ dql_episodes ]Training Episode  876  of  2000
# [ dql_episodes ]Training Episode  877  of  2000
# [ dql_episodes ]Training Episode  878  of  2000
# [ dql_episodes ]Training Episode  879  of  2000
# [ dql_episodes ]Training Episode  880  of  2000
# [ dql_episodes ]Training Episode  881  of  2000
# [ dql_episodes ]Training Episode  882  of  2000
# [ dql_episodes ]Training Episode  883  of  2000
# [ dql_episodes ]Training Episode  884  of  2000
# [ dql_episodes ]Training Episode  885  of  2000
# [ dql_episodes ]Training Episode  886  of  2000
# [ dql_episodes ]Training Episode  887  of  2000
# [ dql_episodes ]Training Episode  888  of  2000
# [ dql_episodes ]Training Episode  889  of  2000
# [ dql_episodes ]Training Episode  890  of  2000
# [ dql_episodes ]Training Episode  891  of  2000
# [ dql_episodes ]Training Episode  892  of  2000
# [ dql_episodes ]Training Episode  893  of  2000
# [ dql_episodes ]Training Episode  894  of  2000
# [ dql_episodes ]Training Episode  895  of  2000
# [ dql_episodes ]Training Episode  896  of  2000
# [ dql_episodes ]Training Episode  897  of  2000
# [ dql_episodes ]Training Episode  898  of  2000
# [ dql_episodes ]Training Episode  899  of  2000
# [ dql_episodes ]Training Episode  900  of  2000
# [ dql_episodes ]Training Episode  901  of  2000
# [ dql_episodes ]Training Episode  902  of  2000
# [ dql_episodes ]Training Episode  903  of  2000
# [ dql_episodes ]Training Episode  904  of  2000
# [ dql_episodes ]Training Episode  905  of  2000
# [ dql_episodes ]Training Episode  906  of  2000
# [ dql_episodes ]Training Episode  907  of  2000
# [ dql_episodes ]Training Episode  908  of  2000
# [ dql_episodes ]Training Episode  909  of  2000
# [ dql_episodes ]Training Episode  910  of  2000
# [ dql_episodes ]Training Episode  911  of  2000
# [ dql_episodes ]Training Episode  912  of  2000
# [ dql_episodes ]Training Episode  913  of  2000
# [ dql_episodes ]Training Episode  914  of  2000
# [ dql_episodes ]Training Episode  915  of  2000
# [ dql_episodes ]Training Episode  916  of  2000
# [ dql_episodes ]Training Episode  917  of  2000
# [ dql_episodes ]Training Episode  918  of  2000
# [ dql_episodes ]Training Episode  919  of  2000
# [ dql_episodes ]Training Episode  920  of  2000
# [ dql_episodes ]Training Episode  921  of  2000
# [ dql_episodes ]Training Episode  922  of  2000
# [ dql_episodes ]Training Episode  923  of  2000
# [ dql_episodes ]Training Episode  924  of  2000
# [ dql_episodes ]Training Episode  925  of  2000
# [ dql_episodes ]Training Episode  926  of  2000
# [ dql_episodes ]Training Episode  927  of  2000
# [ dql_episodes ]Training Episode  928  of  2000
# [ dql_episodes ]Training Episode  929  of  2000
# [ dql_episodes ]Training Episode  930  of  2000
# [ dql_episodes ]Training Episode  931  of  2000
# [ dql_episodes ]Training Episode  932  of  2000
# [ dql_episodes ]Training Episode  933  of  2000
# [ dql_episodes ]Training Episode  934  of  2000
# [ dql_episodes ]Training Episode  935  of  2000
# [ dql_episodes ]Training Episode  936  of  2000
# [ dql_episodes ]Training Episode  937  of  2000
# [ dql_episodes ]Training Episode  938  of  2000
# [ dql_episodes ]Training Episode  939  of  2000
# [ dql_episodes ]Training Episode  940  of  2000
# [ dql_episodes ]Training Episode  941  of  2000
# [ dql_episodes ]Training Episode  942  of  2000
# [ dql_episodes ]Training Episode  943  of  2000
# [ dql_episodes ]Training Episode  944  of  2000
# [ dql_episodes ]Training Episode  945  of  2000
# [ dql_episodes ]Training Episode  946  of  2000
# [ dql_episodes ]Training Episode  947  of  2000
# [ dql_episodes ]Training Episode  948  of  2000
# [ dql_episodes ]Training Episode  949  of  2000
# [ dql_episodes ]Training Episode  950  of  2000
# [ dql_episodes ]Training Episode  951  of  2000
# [ dql_episodes ]Training Episode  952  of  2000
# [ dql_episodes ]Training Episode  953  of  2000
# [ dql_episodes ]Training Episode  954  of  2000
# [ dql_episodes ]Training Episode  955  of  2000
# [ dql_episodes ]Training Episode  956  of  2000
# [ dql_episodes ]Training Episode  957  of  2000
# [ dql_episodes ]Training Episode  958  of  2000
# [ dql_episodes ]Training Episode  959  of  2000
# [ dql_episodes ]Training Episode  960  of  2000
# [ dql_episodes ]Training Episode  961  of  2000
# [ dql_episodes ]Training Episode  962  of  2000
# [ dql_episodes ]Training Episode  963  of  2000
# [ dql_episodes ]Training Episode  964  of  2000
# [ dql_episodes ]Training Episode  965  of  2000
# [ dql_episodes ]Training Episode  966  of  2000
# [ dql_episodes ]Training Episode  967  of  2000
# [ dql_episodes ]Training Episode  968  of  2000
# [ dql_episodes ]Training Episode  969  of  2000
# [ dql_episodes ]Training Episode  970  of  2000
# [ dql_episodes ]Training Episode  971  of  2000
# [ dql_episodes ]Training Episode  972  of  2000
# [ dql_episodes ]Training Episode  973  of  2000
# [ dql_episodes ]Training Episode  974  of  2000
# [ dql_episodes ]Training Episode  975  of  2000
# [ dql_episodes ]Training Episode  976  of  2000
# [ dql_episodes ]Training Episode  977  of  2000
# [ dql_episodes ]Training Episode  978  of  2000
# [ dql_episodes ]Training Episode  979  of  2000
# [ dql_episodes ]Training Episode  980  of  2000
# [ dql_episodes ]Training Episode  981  of  2000
# [ dql_episodes ]Training Episode  982  of  2000
# [ dql_episodes ]Training Episode  983  of  2000
# [ dql_episodes ]Training Episode  984  of  2000
# [ dql_episodes ]Training Episode  985  of  2000
# [ dql_episodes ]Training Episode  986  of  2000
# [ dql_episodes ]Training Episode  987  of  2000
# [ dql_episodes ]Training Episode  988  of  2000
# [ dql_episodes ]Training Episode  989  of  2000
# [ dql_episodes ]Training Episode  990  of  2000
# [ dql_episodes ]Training Episode  991  of  2000
# [ dql_episodes ]Training Episode  992  of  2000
# [ dql_episodes ]Training Episode  993  of  2000
# [ dql_episodes ]Training Episode  994  of  2000
# [ dql_episodes ]Training Episode  995  of  2000
# [ dql_episodes ]Training Episode  996  of  2000
# [ dql_episodes ]Training Episode  997  of  2000
# [ dql_episodes ]Training Episode  998  of  2000
# [ dql_episodes ]Training Episode  999  of  2000
# [ dql_episodes ]Training Episode  1000  of  2000
# ...
# [ dql_episodes ]Training Episode  1678  of  2000
# [ dql_episodes ]Training Episode  1679  of  2000
# [ dql_episodes ]Training Episode  1680  of  2000
# [ dql_episodes ]Training Episode  1681  of  2000
# [ dql_episodes ]Training Episode  1682  of  2000
# [ dql_episodes ]Training Episode  1683  of  2000
# [ dql_episodes ]Training Episode  1684  of  2000
# [ dql_episodes ]Training Episode  1685  of  2000
# [ dql_episodes ]Training Episode  1686  of  2000
# [ dql_episodes ]Training Episode  1687  of  2000
# [ dql_episodes ]Training Episode  1688  of  2000
# [ dql_episodes ]Training Episode  1689  of  2000
# [ dql_episodes ]Training Episode  1690  of  2000
# [ dql_episodes ]Training Episode  1691  of  2000
# [ dql_episodes ]Training Episode  1692  of  2000
# [ dql_episodes ]Training Episode  1693  of  2000
# [ dql_episodes ]Training Episode  1694  of  2000
# [ dql_episodes ]Training Episode  1695  of  2000
# [ dql_episodes ]Training Episode  1696  of  2000
# [ dql_episodes ]Training Episode  1697  of  2000
# [ dql_episodes ]Training Episode  1698  of  2000
# [ dql_episodes ]Training Episode  1699  of  2000
# [ dql_episodes ]Training Episode  1700  of  2000
# [ dql_episodes ]Training Episode  1701  of  2000
# [ dql_episodes ]Training Episode  1702  of  2000
# [ dql_episodes ]Training Episode  1703  of  2000
# [ dql_episodes ]Training Episode  1704  of  2000
# [ dql_episodes ]Training Episode  1705  of  2000
# [ dql_episodes ]Training Episode  1706  of  2000
# [ dql_episodes ]Training Episode  1707  of  2000
# [ dql_episodes ]Training Episode  1708  of  2000
# [ dql_episodes ]Training Episode  1709  of  2000
# [ dql_episodes ]Training Episode  1710  of  2000
# [ dql_episodes ]Training Episode  1711  of  2000
# [ dql_episodes ]Training Episode  1712  of  2000
# [ dql_episodes ]Training Episode  1713  of  2000
# [ dql_episodes ]Training Episode  1714  of  2000
# [ dql_episodes ]Training Episode  1715  of  2000
# [ dql_episodes ]Training Episode  1716  of  2000
# [ dql_episodes ]Training Episode  1717  of  2000
# [ dql_episodes ]Training Episode  1718  of  2000
# [ dql_episodes ]Training Episode  1719  of  2000
# [ dql_episodes ]Training Episode  1720  of  2000
# [ dql_episodes ]Training Episode  1721  of  2000
# [ dql_episodes ]Training Episode  1722  of  2000
# [ dql_episodes ]Training Episode  1723  of  2000
# [ dql_episodes ]Training Episode  1724  of  2000
# [ dql_episodes ]Training Episode  1725  of  2000
# [ dql_episodes ]Training Episode  1726  of  2000
# [ dql_episodes ]Training Episode  1727  of  2000
# [ dql_episodes ]Training Episode  1728  of  2000
# [ dql_episodes ]Training Episode  1729  of  2000
# [ dql_episodes ]Training Episode  1730  of  2000
# [ dql_episodes ]Training Episode  1731  of  2000
# [ dql_episodes ]Training Episode  1732  of  2000
# [ dql_episodes ]Training Episode  1733  of  2000
# [ dql_episodes ]Training Episode  1734  of  2000
# [ dql_episodes ]Training Episode  1735  of  2000
# [ dql_episodes ]Training Episode  1736  of  2000
# [ dql_episodes ]Training Episode  1737  of  2000
# [ dql_episodes ]Training Episode  1738  of  2000
# [ dql_episodes ]Training Episode  1739  of  2000
# [ dql_episodes ]Training Episode  1740  of  2000
# [ dql_episodes ]Training Episode  1741  of  2000
# [ dql_episodes ]Training Episode  1742  of  2000
# [ dql_episodes ]Training Episode  1743  of  2000
# [ dql_episodes ]Training Episode  1744  of  2000
# [ dql_episodes ]Training Episode  1745  of  2000
# [ dql_episodes ]Training Episode  1746  of  2000
# [ dql_episodes ]Training Episode  1747  of  2000
# [ dql_episodes ]Training Episode  1748  of  2000
# [ dql_episodes ]Training Episode  1749  of  2000
# [ dql_episodes ]Training Episode  1750  of  2000
# [ dql_episodes ]Training Episode  1751  of  2000
# [ dql_episodes ]Training Episode  1752  of  2000
# [ dql_episodes ]Training Episode  1753  of  2000
# [ dql_episodes ]Training Episode  1754  of  2000
# [ dql_episodes ]Training Episode  1755  of  2000
# [ dql_episodes ]Training Episode  1756  of  2000
# [ dql_episodes ]Training Episode  1757  of  2000
# [ dql_episodes ]Training Episode  1758  of  2000
# [ dql_episodes ]Training Episode  1759  of  2000
# [ dql_episodes ]Training Episode  1760  of  2000
# [ dql_episodes ]Training Episode  1761  of  2000
# [ dql_episodes ]Training Episode  1762  of  2000
# [ dql_episodes ]Training Episode  1763  of  2000
# [ dql_episodes ]Training Episode  1764  of  2000
# [ dql_episodes ]Training Episode  1765  of  2000
# [ dql_episodes ]Training Episode  1766  of  2000
# [ dql_episodes ]Training Episode  1767  of  2000
# [ dql_episodes ]Training Episode  1768  of  2000
# [ dql_episodes ]Training Episode  1769  of  2000
# [ dql_episodes ]Training Episode  1770  of  2000
# [ dql_episodes ]Training Episode  1771  of  2000
# [ dql_episodes ]Training Episode  1772  of  2000
# [ dql_episodes ]Training Episode  1773  of  2000
# [ dql_episodes ]Training Episode  1774  of  2000
# [ dql_episodes ]Training Episode  1775  of  2000
# [ dql_episodes ]Training Episode  1776  of  2000
# [ dql_episodes ]Training Episode  1777  of  2000
# [ dql_episodes ]Training Episode  1778  of  2000
# [ dql_episodes ]Training Episode  1779  of  2000
# [ dql_episodes ]Training Episode  1780  of  2000
# [ dql_episodes ]Training Episode  1781  of  2000
# [ dql_episodes ]Training Episode  1782  of  2000
# [ dql_episodes ]Training Episode  1783  of  2000
# [ dql_episodes ]Training Episode  1784  of  2000
# [ dql_episodes ]Training Episode  1785  of  2000
# [ dql_episodes ]Training Episode  1786  of  2000
# [ dql_episodes ]Training Episode  1787  of  2000
# [ dql_episodes ]Training Episode  1788  of  2000
# [ dql_episodes ]Training Episode  1789  of  2000
# [ dql_episodes ]Training Episode  1790  of  2000
# [ dql_episodes ]Training Episode  1791  of  2000
# [ dql_episodes ]Training Episode  1792  of  2000
# [ dql_episodes ]Training Episode  1793  of  2000
# [ dql_episodes ]Training Episode  1794  of  2000
# [ dql_episodes ]Training Episode  1795  of  2000
# [ dql_episodes ]Training Episode  1796  of  2000
# [ dql_episodes ]Training Episode  1797  of  2000
# [ dql_episodes ]Training Episode  1798  of  2000
# [ dql_episodes ]Training Episode  1799  of  2000
# [ dql_episodes ]Training Episode  1800  of  2000
# [ dql_episodes ]Training Episode  1801  of  2000
# [ dql_episodes ]Training Episode  1802  of  2000
# [ dql_episodes ]Training Episode  1803  of  2000
# [ dql_episodes ]Training Episode  1804  of  2000
# [ dql_episodes ]Training Episode  1805  of  2000
# [ dql_episodes ]Training Episode  1806  of  2000
# [ dql_episodes ]Training Episode  1807  of  2000
# [ dql_episodes ]Training Episode  1808  of  2000
# [ dql_episodes ]Training Episode  1809  of  2000
# [ dql_episodes ]Training Episode  1810  of  2000
# [ dql_episodes ]Training Episode  1811  of  2000
# [ dql_episodes ]Training Episode  1812  of  2000
# [ dql_episodes ]Training Episode  1813  of  2000
# [ dql_episodes ]Training Episode  1814  of  2000
# [ dql_episodes ]Training Episode  1815  of  2000
# [ dql_episodes ]Training Episode  1816  of  2000
# [ dql_episodes ]Training Episode  1817  of  2000
# [ dql_episodes ]Training Episode  1818  of  2000
# [ dql_episodes ]Training Episode  1819  of  2000
# [ dql_episodes ]Training Episode  1820  of  2000
# [ dql_episodes ]Training Episode  1821  of  2000
# [ dql_episodes ]Training Episode  1822  of  2000
# [ dql_episodes ]Training Episode  1823  of  2000
# [ dql_episodes ]Training Episode  1824  of  2000
# [ dql_episodes ]Training Episode  1825  of  2000
# [ dql_episodes ]Training Episode  1826  of  2000
# [ dql_episodes ]Training Episode  1827  of  2000
# [ dql_episodes ]Training Episode  1828  of  2000
# [ dql_episodes ]Training Episode  1829  of  2000
# [ dql_episodes ]Training Episode  1830  of  2000
# [ dql_episodes ]Training Episode  1831  of  2000
# [ dql_episodes ]Training Episode  1832  of  2000
# [ dql_episodes ]Training Episode  1833  of  2000
# [ dql_episodes ]Training Episode  1834  of  2000
# [ dql_episodes ]Training Episode  1835  of  2000
# [ dql_episodes ]Training Episode  1836  of  2000
# [ dql_episodes ]Training Episode  1837  of  2000
# [ dql_episodes ]Training Episode  1838  of  2000
# [ dql_episodes ]Training Episode  1839  of  2000
# [ dql_episodes ]Training Episode  1840  of  2000
# [ dql_episodes ]Training Episode  1841  of  2000
# [ dql_episodes ]Training Episode  1842  of  2000
# [ dql_episodes ]Training Episode  1843  of  2000
# [ dql_episodes ]Training Episode  1844  of  2000
# [ dql_episodes ]Training Episode  1845  of  2000
# [ dql_episodes ]Training Episode  1846  of  2000
# [ dql_episodes ]Training Episode  1847  of  2000
# [ dql_episodes ]Training Episode  1848  of  2000
# [ dql_episodes ]Training Episode  1849  of  2000
# [ dql_episodes ]Training Episode  1850  of  2000
# [ dql_episodes ]Training Episode  1851  of  2000
# [ dql_episodes ]Training Episode  1852  of  2000
# [ dql_episodes ]Training Episode  1853  of  2000
# [ dql_episodes ]Training Episode  1854  of  2000
# [ dql_episodes ]Training Episode  1855  of  2000
# [ dql_episodes ]Training Episode  1856  of  2000
# [ dql_episodes ]Training Episode  1857  of  2000
# [ dql_episodes ]Training Episode  1858  of  2000
# [ dql_episodes ]Training Episode  1859  of  2000
# [ dql_episodes ]Training Episode  1860  of  2000
# [ dql_episodes ]Training Episode  1861  of  2000
# [ dql_episodes ]Training Episode  1862  of  2000
# [ dql_episodes ]Training Episode  1863  of  2000
# [ dql_episodes ]Training Episode  1864  of  2000
# [ dql_episodes ]Training Episode  1865  of  2000
# [ dql_episodes ]Training Episode  1866  of  2000
# [ dql_episodes ]Training Episode  1867  of  2000
# [ dql_episodes ]Training Episode  1868  of  2000
# [ dql_episodes ]Training Episode  1869  of  2000
# [ dql_episodes ]Training Episode  1870  of  2000
# [ dql_episodes ]Training Episode  1871  of  2000
# [ dql_episodes ]Training Episode  1872  of  2000
# [ dql_episodes ]Training Episode  1873  of  2000
# [ dql_episodes ]Training Episode  1874  of  2000
# [ dql_episodes ]Training Episode  1875  of  2000
# [ dql_episodes ]Training Episode  1876  of  2000
# [ dql_episodes ]Training Episode  1877  of  2000
# [ dql_episodes ]Training Episode  1878  of  2000
# [ dql_episodes ]Training Episode  1879  of  2000
# [ dql_episodes ]Training Episode  1880  of  2000
# [ dql_episodes ]Training Episode  1881  of  2000
# [ dql_episodes ]Training Episode  1882  of  2000
# [ dql_episodes ]Training Episode  1883  of  2000
# [ dql_episodes ]Training Episode  1884  of  2000
# [ dql_episodes ]Training Episode  1885  of  2000
# [ dql_episodes ]Training Episode  1886  of  2000
# [ dql_episodes ]Training Episode  1887  of  2000
# [ dql_episodes ]Training Episode  1888  of  2000
# [ dql_episodes ]Training Episode  1889  of  2000
# [ dql_episodes ]Training Episode  1890  of  2000
# [ dql_episodes ]Training Episode  1891  of  2000
# [ dql_episodes ]Training Episode  1892  of  2000
# [ dql_episodes ]Training Episode  1893  of  2000
# [ dql_episodes ]Training Episode  1894  of  2000
# [ dql_episodes ]Training Episode  1895  of  2000
# [ dql_episodes ]Training Episode  1896  of  2000
# [ dql_episodes ]Training Episode  1897  of  2000
# [ dql_episodes ]Training Episode  1898  of  2000
# [ dql_episodes ]Training Episode  1899  of  2000
# [ dql_episodes ]Training Episode  1900  of  2000
# [ dql_episodes ]Training Episode  1901  of  2000
# [ dql_episodes ]Training Episode  1902  of  2000
# [ dql_episodes ]Training Episode  1903  of  2000
# [ dql_episodes ]Training Episode  1904  of  2000
# [ dql_episodes ]Training Episode  1905  of  2000
# [ dql_episodes ]Training Episode  1906  of  2000
# [ dql_episodes ]Training Episode  1907  of  2000
# [ dql_episodes ]Training Episode  1908  of  2000
# [ dql_episodes ]Training Episode  1909  of  2000
# [ dql_episodes ]Training Episode  1910  of  2000
# [ dql_episodes ]Training Episode  1911  of  2000
# [ dql_episodes ]Training Episode  1912  of  2000
# [ dql_episodes ]Training Episode  1913  of  2000
# [ dql_episodes ]Training Episode  1914  of  2000
# [ dql_episodes ]Training Episode  1915  of  2000
# [ dql_episodes ]Training Episode  1916  of  2000
# [ dql_episodes ]Training Episode  1917  of  2000
# [ dql_episodes ]Training Episode  1918  of  2000
# [ dql_episodes ]Training Episode  1919  of  2000
# [ dql_episodes ]Training Episode  1920  of  2000
# [ dql_episodes ]Training Episode  1921  of  2000
# [ dql_episodes ]Training Episode  1922  of  2000
# [ dql_episodes ]Training Episode  1923  of  2000
# [ dql_episodes ]Training Episode  1924  of  2000
# [ dql_episodes ]Training Episode  1925  of  2000
# [ dql_episodes ]Training Episode  1926  of  2000
# [ dql_episodes ]Training Episode  1927  of  2000
# [ dql_episodes ]Training Episode  1928  of  2000
# [ dql_episodes ]Training Episode  1929  of  2000
# [ dql_episodes ]Training Episode  1930  of  2000
# [ dql_episodes ]Training Episode  1931  of  2000
# [ dql_episodes ]Training Episode  1932  of  2000
# [ dql_episodes ]Training Episode  1933  of  2000
# [ dql_episodes ]Training Episode  1934  of  2000
# [ dql_episodes ]Training Episode  1935  of  2000
# [ dql_episodes ]Training Episode  1936  of  2000
# [ dql_episodes ]Training Episode  1937  of  2000
# [ dql_episodes ]Training Episode  1938  of  2000
# [ dql_episodes ]Training Episode  1939  of  2000
# [ dql_episodes ]Training Episode  1940  of  2000
# [ dql_episodes ]Training Episode  1941  of  2000
# [ dql_episodes ]Training Episode  1942  of  2000
# [ dql_episodes ]Training Episode  1943  of  2000
# [ dql_episodes ]Training Episode  1944  of  2000
# [ dql_episodes ]Training Episode  1945  of  2000
# [ dql_episodes ]Training Episode  1946  of  2000
# [ dql_episodes ]Training Episode  1947  of  2000
# [ dql_episodes ]Training Episode  1948  of  2000
# [ dql_episodes ]Training Episode  1949  of  2000
# [ dql_episodes ]Training Episode  1950  of  2000
# [ dql_episodes ]Training Episode  1951  of  2000
# [ dql_episodes ]Training Episode  1952  of  2000
# [ dql_episodes ]Training Episode  1953  of  2000
# [ dql_episodes ]Training Episode  1954  of  2000
# [ dql_episodes ]Training Episode  1955  of  2000
# [ dql_episodes ]Training Episode  1956  of  2000
# [ dql_episodes ]Training Episode  1957  of  2000
# [ dql_episodes ]Training Episode  1958  of  2000
# [ dql_episodes ]Training Episode  1959  of  2000
# [ dql_episodes ]Training Episode  1960  of  2000
# [ dql_episodes ]Training Episode  1961  of  2000
# [ dql_episodes ]Training Episode  1962  of  2000
# [ dql_episodes ]Training Episode  1963  of  2000
# [ dql_episodes ]Training Episode  1964  of  2000
# [ dql_episodes ]Training Episode  1965  of  2000
# [ dql_episodes ]Training Episode  1966  of  2000
# [ dql_episodes ]Training Episode  1967  of  2000
# [ dql_episodes ]Training Episode  1968  of  2000
# [ dql_episodes ]Training Episode  1969  of  2000
# [ dql_episodes ]Training Episode  1970  of  2000
# [ dql_episodes ]Training Episode  1971  of  2000
# [ dql_episodes ]Training Episode  1972  of  2000
# [ dql_episodes ]Training Episode  1973  of  2000
# [ dql_episodes ]Training Episode  1974  of  2000
# [ dql_episodes ]Training Episode  1975  of  2000
# [ dql_episodes ]Training Episode  1976  of  2000
# [ dql_episodes ]Training Episode  1977  of  2000
# [ dql_episodes ]Training Episode  1978  of  2000
# [ dql_episodes ]Training Episode  1979  of  2000
# [ dql_episodes ]Training Episode  1980  of  2000
# [ dql_episodes ]Training Episode  1981  of  2000
# [ dql_episodes ]Training Episode  1982  of  2000
# [ dql_episodes ]Training Episode  1983  of  2000
# [ dql_episodes ]Training Episode  1984  of  2000
# [ dql_episodes ]Training Episode  1985  of  2000
# [ dql_episodes ]Training Episode  1986  of  2000
# [ dql_episodes ]Training Episode  1987  of  2000
# [ dql_episodes ]Training Episode  1988  of  2000
# [ dql_episodes ]Training Episode  1989  of  2000
# [ dql_episodes ]Training Episode  1990  of  2000
# [ dql_episodes ]Training Episode  1991  of  2000
# [ dql_episodes ]Training Episode  1992  of  2000
# [ dql_episodes ]Training Episode  1993  of  2000
# [ dql_episodes ]Training Episode  1994  of  2000
# [ dql_episodes ]Training Episode  1995  of  2000
# [ dql_episodes ]Training Episode  1996  of  2000
# [ dql_episodes ]Training Episode  1997  of  2000
# [ dql_episodes ]Training Episode  1998  of  2000
# [ dql_episodes ]Training Episode  1999  of  2000
# [ dql_episodes ]Training Episode  2000  of  2000
# INFO:tensorflow:Assets written to: /home/reda/Documents/School/Year 3/CM3203 Individual Project/FlappyCopterV1_1/FlappyCopterV1_0/POLICIES/dql_episodes/assets
